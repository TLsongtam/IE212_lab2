# %%
import pyspark

# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()
movie_rdd = sc.textFile("D:\VisualStudio\IE212\lab 3\movies.txt")
occ_rdd = sc.textFile("D:\VisualStudio\IE212\lab 3\occupation.txt")
ratings_rdd = sc.textFile("D:\VisualStudio\IE212\lab 3\ratings")
users_rdd = sc.textFile(r"D:\VisualStudio\IE212\lab 3\users.txt")

# %%
def drop_col_movies(row:str)-> tuple(str):
    movie_id, title, _ = row.split(,)
    return movie_id, title
